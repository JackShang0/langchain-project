# %% [markdown]
# # 1、 获取大模型

# %%
# 导入 dotenv 库 load_dotenv 函数，用于加载环境变量文件（.env）中的配置
import dotenv
from langchain_openai import ChatOpenAI
import os

dotenv.load_dotenv()    # 加载当前目录下的 .env 文件
os.environ.setdefault("OPENAI_API_KEY", os.getenv("OPENAI_API_KEY"))
os.environ.setdefault("OPENAI_BASE_URL", os.getenv("OPENAI_BASE_URL"))

# 创建大模型实例
llm = ChatOpenAI(model="gpt-4o-mini")    # 默认使用gtp-3.5-turbo

# 直接提供问题，并调用llm
response = llm.invoke("什么是大模型")
print(response)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       4 import os
#       6 dotenv.load_dotenv()    # 加载当前目录下的 .env 文件
# ----> 7 os.environ.setdefault("OPENAI_API_KEY", os.getenv("OPENAI_API_KEY"))
#       8 os.environ.setdefault("OPENAI_BASE_URL", os.getenv("OPENAI_BASE_URL"))
#      10 # 创建大模型实例
#
# File <frozen os>:718, in setdefault(self, key, value)
#
# File <frozen os>:684, in __setitem__(self, key, value)
#
# File <frozen os>:744, in check_str(value)
#
# TypeError: str expected, not NoneType
